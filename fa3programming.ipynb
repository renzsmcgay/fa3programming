# %% [markdown]
# <a href="https://colab.research.google.com/github/renzsmcgay/fa3programming/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = str(input("Enter Name "))
age = str(input("Enter Age "))
course = str(input("Enter course "))

print("Name:", name)
print("Age:", age)
print("Course:", course)
# Out:
# Enter Name renz
# Enter Age 67
# Enter course engineering
# Name: renz
# Age: 67
# Course: engineering

# %%
name = str(input("Enter name "))
score = int(input("Enter score "))

if score < 0:
 print("Invalid score, try again")
if score > 100:
 print("Invalid score, try again")
if score >= 90 and score <= 100:
 print(" A ")
if score >= 80 and score <= 89:
 print(" B ")
if score >= 70 and score <= 79:
 print(" C ")
if score < 70:
 print(" F ")
# Out:
# Enter name mulato
# Enter score 69
#  F

# %%
score = int(input("Input score "))

if score < 0:
 print("Invalid score, please input again")
if score > 100:
 print("Invalid score, please try again")
if score < 75:
 print("Failed")
else:
 print("Passed")
# Out:
# Input score 67
# Failed
